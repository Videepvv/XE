# %%
import pandas as pd

# Load the files
for group in range (1,11):
    oracle_path = f'Group_{group:02}_Oracle (1).csv'
    dped_path = f'../Group_{group:02}_DPed.csv'

    oracle_df = pd.read_csv(oracle_path)
    dped_df = pd.read_csv(dped_path)

    # Merge the two dataframes based on the 'Utterance' column
    # Keeping all columns from oracle_df and only the 'DPed' column from dped_df
    merged_df = pd.merge(oracle_df, dped_df[['Utterance', 'DPed']], on='Utterance', how='left')

    # Only update the 'Transcript' where 'DPed' is not NaN
    merged_df.loc[~merged_df['DPed'].isna(), 'Transcript'] = merged_df['DPed']

    # Drop the now redundant 'DPed' column
    merged_df.drop(columns=['DPed'], inplace=True)

    # Save the updated dataframe to a new CSV file
    updated_file_path = f'Group_{group:02}_Oracle.csv'
    merged_df.to_csv(updated_file_path, index=False)

# %%
import pandas as pd
import re
# Function to find overlap between two intervals
def is_overlap(start1, end1, start2, end2):
    return max(start1, start2) < min(end1, end2)


#The following will find the greatest overlap betwween the CGA segments and the oracle segments  
#If there are multiple overlapping segments, then the oracle with the longer transcript will be chosen
#The final output will contain the CGA labels with its corresponding transcript 
for group in range(1, 11):
    print(f"Processing Group {group}")
    # Load the Oracle and CGA CSV files
    oracle_path = f"Group_{group:02}_Oracle.csv" # We just created it in the above cell 
    cga_path = f"Group_{group:02}_CGA (1).csv"  # Corrected path for CGA file

    oracle_df = pd.read_csv(oracle_path)
    cga_df = pd.read_csv(cga_path)

    # Convert time stamps to float
    oracle_df['Start'] = oracle_df['Start'].astype(float)
    oracle_df['End'] = oracle_df['End'].astype(float)
    cga_df['Begin Time - ss.msec'] = cga_df['Begin Time - ss.msec'].astype(float)
    cga_df['End Time - ss.msec'] = cga_df['End Time - ss.msec'].astype(float)

    # Create a new column in CGA for each Oracle column to be merged
    for col in oracle_df.columns:
        if col not in cga_df:
            cga_df[col] = None

    # Iterate through each row in CGA and check for overlap with Oracle rows
    for index, cga_row in cga_df.iterrows():
        cga_start = cga_row['Begin Time - ss.msec']
        cga_end = cga_row['End Time - ss.msec']
        best_overlap_row = None
        max_transcript_length = -1

        for _, oracle_row in oracle_df.iterrows():
            oracle_start = oracle_row['Start']
            oracle_end = oracle_row['End']

            # Check for overlap
            if is_overlap(cga_start, cga_end, oracle_start, oracle_end):
                transcript_length = len(oracle_row['Transcript'])
                
                # Select the row with the longer transcript
                if transcript_length > max_transcript_length:
                    best_overlap_row = oracle_row
                    max_transcript_length = transcript_length

        # If an overlapping row is found, merge it into CGA row
        if best_overlap_row is not None:
            for col in oracle_df.columns:
                cga_df.at[index, col] = best_overlap_row[col]

    # Save the modified CGA dataframe to a new CSV file
    modified_cga_path = f'Golden_Group_{group:02}_CGA.csv'
    cga_df['Common Ground'] = cga_df['Common Ground'].astype(str)

    # Filtering rows where 'Common Ground' contains 'STATEMENT'
    statement_rows = cga_df[cga_df['Common Ground'].str.contains('STATEMENT')]
    print(statement_rows)

    # Define a function to extract content within brackets
    def extract_brackets(text):
        match = re.search(r'\((.*?)\)', text)
        if match:
            return match.group(1)
        else:
            return "No Match Found"  # Return a placeholder if no match is found

    def replace_symbols(text):
        text.replace("equals","=").replace("does not equal","!=").\
                        replace("is less than","<").replace("is more than",">").\
                        replace("plus","+").replace("ten","10").replace("twenty","20").replace("thirty","30").\
                        replace("forty","40").replace("fifty","50").replace("block","").replace(" and ", ",").\
                        replace(" ","")
    # Apply the function to the 'Common Ground' column
    statement_rows.loc[:, 'Common Ground'] = statement_rows['Common Ground'].apply(extract_brackets)
    print(statement_rows)
    statement_rows.to_csv(modified_cga_path)
# Out:
# Processing Group 1
#     Begin Time - ss.msec  End Time - ss.msec  \
# 0                  24.42               27.72
# 2                  80.52               81.67
# 5                  95.19               97.17
# 7                  99.78              102.03
# 12                112.42              112.72
# 13                112.74              113.76
# 16                127.35              129.19
# 18                129.47              131.98
# 22                140.73              142.81
# 29                181.08              182.28
# 35                207.06              210.87
# 40                238.04              239.92
# 45                265.50              268.13
#
#                                         Common Ground Utterance   Start  \
# 0                             S0: STATEMENT(red = 10)         5   24.42
# 2                             S1: STATEMENT(red = 10)        24   78.08
# 5                           S2: STATEMENT(red = blue)        30   95.19
# 7                            S3: STATEMENT(blue = 10)        31   97.56
# 12                         S4: STATEMENT(purple > 20)        36  110.16
# 13                      S5: STATEMENT: (purple != 20)        36  110.16
# 16                          S6: STATEMENT(green = 20)        41  127.35
# 18  S7: STATEMENT(S209: STATEMENT(red = 10 and blu...        41  127.35
# 22                         S9: STATEMENT(purple = 30)        47  140.73
# 29       S10: STATEMENT(yellow > purple + red + blue)        57  174.54
# 35  S11: STATEMENT(red = 10, blue = 10, green = 20...        65  207.06
# 40                        S12: STATEMENT(yellow < 50)        73  234.27
# 45                        S13: STATEMENT(yellow = 50)        81  268.08
#
#        End Group Participant  \
# 0    27.72     1           4
# 2    80.58     1           1
# 5    97.17     1           3
# 7   102.03     1           1
# 12  114.24     1           1
# 13  114.24     1           1
# 16   132.0     1           2
# 18   132.0     1           2
# 22  145.89     1           1
# 29  185.08     1           2
# 35  210.87     1           1
# 40  239.82     1           1
# 45  272.58     1           3
#
#                                            Transcript
# 0   And we will tell you that this red cube on top...
# 2           ok well red block would be nine minus ten
# 5         red block, blue block seems pretty balanced
# 7   yeah ok so now we know that blue block is also...
# 12  And then see if there's thats twenty which is not
# 13  And then see if there's thats twenty which is not
# 16  ok so green block one is probably twenty ten t...
# 18  ok so green block one is probably twenty ten t...
# 22                        Ooh its looking like thirty
# 29  yeah yeah the blue dark blue one is thirty pur...
# 35  yeah im thinking that red block, blue block, g...
# 40  thirty fourty fifty correct and purple block, ...
# 45               yeah fifty so we say yellow is fifty
#     Begin Time - ss.msec  End Time - ss.msec  \
# 0                  24.42               27.72
# 2                  80.52               81.67
# 5                  95.19               97.17
# 7                  99.78              102.03
# 12                112.42              112.72
# 13                112.74              113.76
# 16                127.35              129.19
# 18                129.47              131.98
# 22                140.73              142.81
# 29                181.08              182.28
# 35                207.06              210.87
# 40                238.04              239.92
# 45                265.50              268.13
#
#                                         Common Ground Utterance   Start  \
# 0                                            red = 10         5   24.42
# 2                                            red = 10        24   78.08
# 5                                          red = blue        30   95.19
# 7                                           blue = 10        31   97.56
# 12                                        purple > 20        36  110.16
# 13                                       purple != 20        36  110.16
# 16                                         green = 20        41  127.35
# 18  S209: STATEMENT(red = 10 and blue = 10 and gre...        41  127.35
# 22                                        purple = 30        47  140.73
# 29                       yellow > purple + red + blue        57  174.54
# 35       red = 10, blue = 10, green = 20, purple = 30        65  207.06
# 40                                        yellow < 50        73  234.27
# 45                                        yellow = 50        81  268.08
#
#        End Group Participant  \
# 0    27.72     1           4
# 2    80.58     1           1
# 5    97.17     1           3
# 7   102.03     1           1
# 12  114.24     1           1
# 13  114.24     1           1
# 16   132.0     1           2
# 18   132.0     1           2
# 22  145.89     1           1
# 29  185.08     1           2
# 35  210.87     1           1
# 40  239.82     1           1
# 45  272.58     1           3
#
#                                            Transcript
# 0   And we will tell you that this red cube on top...
# 2           ok well red block would be nine minus ten
# 5         red block, blue block seems pretty balanced
# 7   yeah ok so now we know that blue block is also...
# 12  And then see if there's thats twenty which is not
# 13  And then see if there's thats twenty which is not
# 16  ok so green block one is probably twenty ten t...
# 18  ok so green block one is probably twenty ten t...
# 22                        Ooh its looking like thirty
# 29  yeah yeah the blue dark blue one is thirty pur...
# 35  yeah im thinking that red block, blue block, g...
# 40  thirty fourty fifty correct and purple block, ...
# 45               yeah fifty so we say yellow is fifty
# Processing Group 2
#     Begin Time - ss.msec  End Time - ss.msec  \
# 0                  23.52               26.76
# 1                  88.98               91.58
# 2                 104.08              106.23
# 4                 124.68              127.02
# 5                 144.92              149.08
# 7                 152.31              153.75
# 9                 158.13              164.17
# 12                192.69              195.87
# 14                221.40              225.41
# 17                237.51              241.77
# 18                247.95              250.17
# 19                255.36              258.01
# 21                264.30              268.65
# 22                271.92              275.16
#
#                                  Common Ground Utterance   Start     End  \
# 0                      S0: STATEMENT(red =10)          3   23.52   32.73
# 1                    S1: STATEMENT(red = blue)        15   88.98   91.58
# 2                     S2: STATEMENT(blue = 10)        20  104.08  106.23
# 4            S4: STATEMENT(green = red + blue)        28  124.68  127.02
# 5                    S5: STATEMENT(green = 20)        31  141.27  146.91
# 7        S6: STATEMENT(red = 10 and blue = 10)        34  152.31  153.75
# 9                    S7: STATEMENT(green = 20)        37  158.13  164.17
# 12                  S8: STATEMENT(purple = 30)        42  192.69  195.87
# 14                  S9: STATEMENT(purple = 30)        47   221.4  225.41
# 17             S10: STATEMENT(yellow > purple)        52  237.51  241.77
# 18  S12: STATEMENT(green = 20 and purple = 30)        53  247.95  250.17
# 19     S13: STATEMENT(yellow < green + purple)        54  255.36  258.01
# 21      S14: STATEMENT(yellow > blue + purple)        56   264.3  268.65
# 22                 S14: STATEMENT(yellow = 50)        59  271.92  275.16
#
#    Group Participant                                         Transcript
# 0      2           4  And we can tell you that that red cube right t...
# 1      2           1  needle goes over the red line that means red b...
# 2      2           1        so blue block one is probably ten grams too
# 4      2           2         and that looks like it might be about even
# 5      2           2  well on the first go through i noticed how it ...
# 7      2           1                              The first two are ten
# 9      2           2  so knowing that uh oh sorry the green one was ...
# 12     2           1        So you know twenty plus ten thirty probably
# 14     2           2  i guess and there's no increment so five so we...
# 17     2           1        Which is too much so we'll put twenty right
# 18     2           2  so purple block, green block's the twenty and ...
# 19     2           2           it's leaning towards one side a bit much
# 21     2           1                          Oh not enough so probably
# 22     2           2  Oh yeah the twenty and the thirty so we'll go ...
#     Begin Time - ss.msec  End Time - ss.msec               Common Ground  \
# 0                  23.52               26.76                     red =10
# 1                  88.98               91.58                  red = blue
# 2                 104.08              106.23                   blue = 10
# 4                 124.68              127.02          green = red + blue
# 5                 144.92              149.08                  green = 20
# 7                 152.31              153.75      red = 10 and blue = 10
# 9                 158.13              164.17                  green = 20
# 12                192.69              195.87                 purple = 30
# 14                221.40              225.41                 purple = 30
# 17                237.51              241.77             yellow > purple
# 18                247.95              250.17  green = 20 and purple = 30
# 19                255.36              258.01     yellow < green + purple
# 21                264.30              268.65      yellow > blue + purple
# 22                271.92              275.16                 yellow = 50
#
#    Utterance   Start     End Group Participant  \
# 0          3   23.52   32.73     2           4
# 1         15   88.98   91.58     2           1
# 2         20  104.08  106.23     2           1
# 4         28  124.68  127.02     2           2
# 5         31  141.27  146.91     2           2
# 7         34  152.31  153.75     2           1
# 9         37  158.13  164.17     2           2
# 12        42  192.69  195.87     2           1
# 14        47   221.4  225.41     2           2
# 17        52  237.51  241.77     2           1
# 18        53  247.95  250.17     2           2
# 19        54  255.36  258.01     2           2
# 21        56   264.3  268.65     2           1
# 22        59  271.92  275.16     2           2
#
#                                            Transcript
# 0   And we can tell you that that red cube right t...
# 1   needle goes over the red line that means red b...
# 2         so blue block one is probably ten grams too
# 4          and that looks like it might be about even
# 5   well on the first go through i noticed how it ...
# 7                               The first two are ten
# 9   so knowing that uh oh sorry the green one was ...
# 12        So you know twenty plus ten thirty probably
# 14  i guess and there's no increment so five so we...
# 17        Which is too much so we'll put twenty right
# 18  so purple block, green block's the twenty and ...
# 19           it's leaning towards one side a bit much
# 21                          Oh not enough so probably
# 22  Oh yeah the twenty and the thirty so we'll go ...
# Processing Group 3
#     Begin Time - ss.msec  End Time - ss.msec  \
# 0                  33.39               38.04
# 3                 142.38              145.07
# 7                 212.13              214.16
# 10                238.47              240.45
# 13                269.35              272.58
# 15                277.53              279.75
# 16                279.77              281.42
# 17                285.18              287.82
# 21                314.10              315.58
# 23                336.06              338.42
# 24                344.01              348.36
# 27                366.06              371.16
# 28                399.16              402.03
# 29                431.58              435.75
#
#                                         Common Ground Utterance   Start  \
# 0                             S0: STATEMENT(red = 10)         2   33.39
# 3                           S1: STATEMENT(red = blue)        16   144.5
# 7                           S2: STATEMENT(green = 20)        31  212.13
# 10                         S3: STATEMENT(purple = 30)        36  238.47
# 13  S4: STATEMENT(green = 20 and purple = 30 and y...        46  269.35
# 15                          S5: STATEMENT(green = 20)        48  277.53
# 16             S6: STATEMENT(yellow < green + purple)        49  277.92
# 17             S7: STATEMENT(yellow < green + purple)        50  285.18
# 21                        S7: STATEMENT(yellow != 10)        57   314.1
# 23         S8: STATEMENT(yellow > green + blue + red)        63  337.33
# 24                         S9: STATEMENT(yellow = 50)        64  344.01
# 27                       S10: STATEMENT(yellow != 30)        68  366.06
# 28                        S11: STATEMENT(yellow = 50)        71  396.69
# 29        S12: STATEMENT(purple = 30 and yellow = 50)        78  432.25
#
#        End Group Participant  \
# 0    38.04     3           4
# 3   147.27     3           1
# 7   214.16     3           1
# 10  240.45     3           2
# 13  272.58     3           3
# 15  279.75     3           3
# 16  281.43     3           2
# 17  287.82     3           2
# 21  315.58     3           3
# 23  341.55     3           3
# 24  348.36     3           3
# 27  371.16     3           2
# 28  404.73     3           1
# 29  433.84     3           3
#
#                                            Transcript
# 0   We will tell you that the weight of the red cu...
# 3   i think red block, blue block're the same weig...
# 7   sufficient to say green block one's probably t...
# 10                           the purple one is thirty
# 13  green is twenty and purple is thirty so yellow...
# 15              yeah i mentioned here green is twenty
# 16                     it's leaning more this side so
# 17                      it's leaning more to the side
# 21                    yellow is of course not ten but
# 23   no so when we try purple block, green block both
# 24                          so i feel yellow is fifty
# 27                 yellow block's for sure not thirty
# 28  yellow block must be red block, blue block, pu...
# 29                     yeah and yellow block is fifty
#     Begin Time - ss.msec  End Time - ss.msec  \
# 0                  33.39               38.04
# 3                 142.38              145.07
# 7                 212.13              214.16
# 10                238.47              240.45
# 13                269.35              272.58
# 15                277.53              279.75
# 16                279.77              281.42
# 17                285.18              287.82
# 21                314.10              315.58
# 23                336.06              338.42
# 24                344.01              348.36
# 27                366.06              371.16
# 28                399.16              402.03
# 29                431.58              435.75
#
#                                  Common Ground Utterance   Start     End  \
# 0                                     red = 10         2   33.39   38.04
# 3                                   red = blue        16   144.5  147.27
# 7                                   green = 20        31  212.13  214.16
# 10                                 purple = 30        36  238.47  240.45
# 13  green = 20 and purple = 30 and yellow = 50        46  269.35  272.58
# 15                                  green = 20        48  277.53  279.75
# 16                     yellow < green + purple        49  277.92  281.43
# 17                     yellow < green + purple        50  285.18  287.82
# 21                                yellow != 10        57   314.1  315.58
# 23                 yellow > green + blue + red        63  337.33  341.55
# 24                                 yellow = 50        64  344.01  348.36
# 27                                yellow != 30        68  366.06  371.16
# 28                                 yellow = 50        71  396.69  404.73
# 29                 purple = 30 and yellow = 50        78  432.25  433.84
#
#    Group Participant                                         Transcript
# 0      3           4  We will tell you that the weight of the red cu...
# 3      3           1  i think red block, blue block're the same weig...
# 7      3           1  sufficient to say green block one's probably t...
# 10     3           2                           the purple one is thirty
# 13     3           3  green is twenty and purple is thirty so yellow...
# 15     3           3              yeah i mentioned here green is twenty
# 16     3           2                     it's leaning more this side so
# 17     3           2                      it's leaning more to the side
# 21     3           3                    yellow is of course not ten but
# 23     3           3   no so when we try purple block, green block both
# 24     3           3                          so i feel yellow is fifty
# 27     3           2                 yellow block's for sure not thirty
# 28     3           1  yellow block must be red block, blue block, pu...
# 29     3           3                     yeah and yellow block is fifty
# Processing Group 4
#     Begin Time - ss.msec  End Time - ss.msec                Common Ground  \
# 0                  33.30               36.23      S0: STATEMENT(red = 10)
# 5                  81.61               82.96     S1: STATEMENT(blue = 10)
# 8                  91.14               91.75    S2: STATEMENT(green = 20)
# 18                121.58              123.64   S3: STATEMENT(purple = 30)
# 21                125.49              127.16  S4: STATEMENT(purple != 40)
# 23                127.96              129.29  S5: STATEMENT(purple != 20)
# 24                129.51              130.62   S6: STATEMENT(purple = 30)
# 28                157.84              159.83   S7: STATEMENT(yellow = 50)
# 30                161.88              162.59     S8: STATEMENT(blue = 10)
# 34                174.37              175.44   S9: STATEMENT(yellow = 50)
#
#    Utterance   Start     End Group Participant  \
# 0          6    33.3   36.24     4           4
# 5         16   80.79    83.1     4           1
# 8         19   89.82   97.32     4           1
# 18        28  119.94  125.75     4           1
# 21        28  119.94  125.75     4           1
# 23        31  127.47  130.62     4           2
# 24        31  127.47  130.62     4           2
# 28        40  155.04  161.79     4           3
# 30        43  161.88  162.59     4           1
# 34        48  170.46  177.06     4           3
#
#                                            Transcript
# 0      I will tell you that the red cube is ten grams
# 5                               Well the top is a ten
# 8   ok there easy so green block is twenty yeah ca...
# 18  it doesn't drop completely yeah we can conside...
# 21  it doesn't drop completely yeah we can conside...
# 23  well purple block's not and purple block's not...
# 24  well purple block's not and purple block's not...
# 28  uh so yellow we or red and blue there's no the...
# 30                                        blue is ten
# 34             and so that would mean yellow is fifty
#     Begin Time - ss.msec  End Time - ss.msec Common Ground Utterance   Start  \
# 0                  33.30               36.23      red = 10         6    33.3
# 5                  81.61               82.96     blue = 10        16   80.79
# 8                  91.14               91.75    green = 20        19   89.82
# 18                121.58              123.64   purple = 30        28  119.94
# 21                125.49              127.16  purple != 40        28  119.94
# 23                127.96              129.29  purple != 20        31  127.47
# 24                129.51              130.62   purple = 30        31  127.47
# 28                157.84              159.83   yellow = 50        40  155.04
# 30                161.88              162.59     blue = 10        43  161.88
# 34                174.37              175.44   yellow = 50        48  170.46
#
#        End Group Participant  \
# 0    36.24     4           4
# 5     83.1     4           1
# 8    97.32     4           1
# 18  125.75     4           1
# 21  125.75     4           1
# 23  130.62     4           2
# 24  130.62     4           2
# 28  161.79     4           3
# 30  162.59     4           1
# 34  177.06     4           3
#
#                                            Transcript
# 0      I will tell you that the red cube is ten grams
# 5                               Well the top is a ten
# 8   ok there easy so green block is twenty yeah ca...
# 18  it doesn't drop completely yeah we can conside...
# 21  it doesn't drop completely yeah we can conside...
# 23  well purple block's not and purple block's not...
# 24  well purple block's not and purple block's not...
# 28  uh so yellow we or red and blue there's no the...
# 30                                        blue is ten
# 34             and so that would mean yellow is fifty
# Processing Group 5
#     Begin Time - ss.msec  End Time - ss.msec  \
# 0                  20.24               22.70
# 1                  62.91               64.62
# 3                  92.25               95.19
# 5                 108.58              112.17
# 7                 131.62              132.99
# 9                 134.19              136.63
# 10                147.96              154.32
# 11                154.47              159.75
# 13                164.07              168.25
# 15                174.48              183.63
# 17                199.38              200.84
# 18                207.25              218.67
# 19                218.73              226.08
# 21                233.58              236.64
# 22                244.17              246.57
#
#                                         Common Ground Utterance   Start  \
# 0                             S0: STATEMENT(red = 10)         3   20.25
# 1                             S1: STATEMENT(red = 10)        14   60.08
# 3                           S2: STATEMENT(red = blue)        24   92.25
# 5               S3: STATEMENT(red = 10 and blue = 10)        28  108.33
# 7                           S4: STATEMENT(green = 20)        33  131.62
# 9   S5: STATEMENT(red = 10 and blue = 10 and green...        34  133.33
# 10                          S6: STATEMENT(green = 20)        39  147.96
# 11                      S7: STATEMENT(purple > green)        41  154.47
# 13                         S8: STATEMENT(purple > 20)        45  164.07
# 15                         S9: STATEMENT(purple = 30)        50  174.48
# 17         S10: STATEMENT(purple = 30 and green = 20)        57  199.38
# 18                        S11: STATEMENT(yellow = 50)        59  205.77
# 19                        S12: STATEMENT(yellow = 50)        62  218.73
# 21        S13: STATEMENT(yellow = 50 and purple = 30)        68  233.58
# 22                        S14: STATEMENT(purple = 30)        71  242.34
#
#        End Group Participant  \
# 0    22.68     5           4
# 1    64.08     5           1
# 3    95.19     5           1
# 5   112.17     5           1
# 7   132.99     5           2
# 9   136.65     5           2
# 10  154.32     5           3
# 11  159.75     5           1
# 13  168.25     5           1
# 15  183.63     5           2
# 17  200.84     5           1
# 18  218.67     5           1
# 19  226.08     5           2
# 21  236.64     5           1
# 22  246.57     5           1
#
#                                            Transcript
# 0       I can tell you that the red cube is ten grams
# 1   alright reese you can fill out the survey on t...
# 3   i'd say red block, blue block's basically the ...
# 5   ok so yeah that scale so red block, blue block...
# 7                         so green block one's twenty
# 9   so red block, blue block are both ten in theor...
# 10  so the green we think is twenty ok so let's se...
# 11  purple block is heavier than green block one s...
# 13  ok so purple block's heavier ok ok so greather...
# 15  teeter teeter we know purple block's less than...
# 17                                      Thirty twenty
# 18  purple block, green block looks almost a littl...
# 19  and purple block is thirty right and red block...
# 21  i think yellow block is fifty and purple block...
# 22   yeah let's go thirty ok so purple block's thirty
#     Begin Time - ss.msec  End Time - ss.msec  \
# 0                  20.24               22.70
# 1                  62.91               64.62
# 3                  92.25               95.19
# 5                 108.58              112.17
# 7                 131.62              132.99
# 9                 134.19              136.63
# 10                147.96              154.32
# 11                154.47              159.75
# 13                164.07              168.25
# 15                174.48              183.63
# 17                199.38              200.84
# 18                207.25              218.67
# 19                218.73              226.08
# 21                233.58              236.64
# 22                244.17              246.57
#
#                             Common Ground Utterance   Start     End Group  \
# 0                                red = 10         3   20.25   22.68     5
# 1                                red = 10        14   60.08   64.08     5
# 3                              red = blue        24   92.25   95.19     5
# 5                  red = 10 and blue = 10        28  108.33  112.17     5
# 7                              green = 20        33  131.62  132.99     5
# 9   red = 10 and blue = 10 and green = 20        34  133.33  136.65     5
# 10                             green = 20        39  147.96  154.32     5
# 11                         purple > green        41  154.47  159.75     5
# 13                            purple > 20        45  164.07  168.25     5
# 15                            purple = 30        50  174.48  183.63     5
# 17             purple = 30 and green = 20        57  199.38  200.84     5
# 18                            yellow = 50        59  205.77  218.67     5
# 19                            yellow = 50        62  218.73  226.08     5
# 21            yellow = 50 and purple = 30        68  233.58  236.64     5
# 22                            purple = 30        71  242.34  246.57     5
#
#    Participant                                         Transcript
# 0            4      I can tell you that the red cube is ten grams
# 1            1  alright reese you can fill out the survey on t...
# 3            1  i'd say red block, blue block's basically the ...
# 5            1  ok so yeah that scale so red block, blue block...
# 7            2                        so green block one's twenty
# 9            2  so red block, blue block are both ten in theor...
# 10           3  so the green we think is twenty ok so let's se...
# 11           1  purple block is heavier than green block one s...
# 13           1  ok so purple block's heavier ok ok so greather...
# 15           2  teeter teeter we know purple block's less than...
# 17           1                                      Thirty twenty
# 18           1  purple block, green block looks almost a littl...
# 19           2  and purple block is thirty right and red block...
# 21           1  i think yellow block is fifty and purple block...
# 22           1   yeah let's go thirty ok so purple block's thirty
# Processing Group 6
#     Begin Time - ss.msec  End Time - ss.msec  \
# 0                  21.12               24.51
# 1                  63.42               66.00
# 2                  72.45               76.17
# 5                  89.76               91.06
# 6                 102.35              104.28
# 8                 116.79              125.37
# 10                141.18              146.85
# 11                156.33              161.08
# 14                177.57              178.08
# 16                186.24              190.92
# 17                192.61              195.21
# 18                195.24              196.42
# 19                201.21              202.25
# 20                205.44              209.58
# 22                224.50              226.56
# 23                237.36              240.75
#
#                                  Common Ground Utterance   Start     End  \
# 0                      S0: STATEMENT(red = 10)         3   21.12   24.51
# 1                      S1: STATEMENT(red = 10)         9   61.23   64.67
# 2                    S2: STATEMENT(red = blue)        11   72.45   76.17
# 5           S3: STATEMENT(purple > red + blue)        14   89.76   91.06
# 6                    S4: STATEMENT(green = 20)        18   102.3   103.5
# 8       S5: STATEMENT(red = 10 and green = 20)        24  116.79  125.37
# 10  S6: STATEMENT(purple > 20 and purple < 30)        32  141.18  146.85
# 11                  S7: STATEMENT(purple = 30)        34  157.58  159.58
# 14                  S8: STATEMENT(yellow = 50)        41  177.57  178.08
# 16                  S9: STATEMENT(yellow < 50)        44  186.24  190.92
# 17  S10: STATEMENT(purple = 30 and green = 20)        46  192.61  195.21
# 18     S11: STATEMENT( red = 10 and blue = 10)        47  195.24  196.42
# 19     S12: STATEMENT(yellow < purple + green)        49  201.21  202.25
# 20         S13: STATEMENT(purple + green = 50)        51  205.44  209.58
# 22          S14: STATEMENT(purple + blue = 40)        57   224.5  226.56
# 23                 S15: STATEMENT(yellow = 50)        59  239.41  243.39
#
#    Group Participant                                         Transcript
# 0      6           4     I will tell you that the red cube is ten grams
# 1      6           1           i guess if red block red one's ten grams
# 2      6           1  seems like red block, blue block might be abou...
# 5      6           3                                       Too heavy so
# 6      6           1                         that's looking pretty even
# 8      6           2  it's just stuff written at the bottom that's a...
# 10     6           2  ok so purple block's more than twenty but it a...
# 11     6           2  if red block, blue block, green block, yellow ...
# 14     6           2                                              Fifty
# 16     6           3  yeah purple block, green block's considerably ...
# 17     6           2         yeah purple block's thirty green is twenty
# 18     6           2                    red and small blue are both ten
# 19     6           3          but green block, purple block's too heavy
# 20     6           1  purple block, green block is fifty on here so ...
# 22     6           2  so purple block, blue block should be forty ri...
# 23     6           2  i would say yellow is like forty five but we c...
#     Begin Time - ss.msec  End Time - ss.msec                Common Ground  \
# 0                  21.12               24.51                     red = 10
# 1                  63.42               66.00                     red = 10
# 2                  72.45               76.17                   red = blue
# 5                  89.76               91.06          purple > red + blue
# 6                 102.35              104.28                   green = 20
# 8                 116.79              125.37      red = 10 and green = 20
# 10                141.18              146.85  purple > 20 and purple < 30
# 11                156.33              161.08                  purple = 30
# 14                177.57              178.08                  yellow = 50
# 16                186.24              190.92                  yellow < 50
# 17                192.61              195.21   purple = 30 and green = 20
# 18                195.24              196.42       red = 10 and blue = 10
# 19                201.21              202.25      yellow < purple + green
# 20                205.44              209.58          purple + green = 50
# 22                224.50              226.56           purple + blue = 40
# 23                237.36              240.75                  yellow = 50
#
#    Utterance   Start     End Group Participant  \
# 0          3   21.12   24.51     6           4
# 1          9   61.23   64.67     6           1
# 2         11   72.45   76.17     6           1
# 5         14   89.76   91.06     6           3
# 6         18   102.3   103.5     6           1
# 8         24  116.79  125.37     6           2
# 10        32  141.18  146.85     6           2
# 11        34  157.58  159.58     6           2
# 14        41  177.57  178.08     6           2
# 16        44  186.24  190.92     6           3
# 17        46  192.61  195.21     6           2
# 18        47  195.24  196.42     6           2
# 19        49  201.21  202.25     6           3
# 20        51  205.44  209.58     6           1
# 22        57   224.5  226.56     6           2
# 23        59  239.41  243.39     6           2
#
#                                            Transcript
# 0      I will tell you that the red cube is ten grams
# 1            i guess if red block red one's ten grams
# 2   seems like red block, blue block might be abou...
# 5                                        Too heavy so
# 6                          that's looking pretty even
# 8   it's just stuff written at the bottom that's a...
# 10  ok so purple block's more than twenty but it a...
# 11  if red block, blue block, green block, yellow ...
# 14                                              Fifty
# 16  yeah purple block, green block's considerably ...
# 17         yeah purple block's thirty green is twenty
# 18                    red and small blue are both ten
# 19          but green block, purple block's too heavy
# 20  purple block, green block is fifty on here so ...
# 22  so purple block, blue block should be forty ri...
# 23  i would say yellow is like forty five but we c...
# Processing Group 7
#     Begin Time - ss.msec  End Time - ss.msec  \
# 0                  30.90               34.59
# 1                 107.31              109.09
# 3                 139.87              142.15
# 6                 152.57              153.59
# 7                 179.32              181.84
# 8                 192.91              194.92
# 9                 212.92              213.95
# 12                395.75              397.25
# 16                458.08              458.84
#
#                                 Common Ground Utterance   Start     End Group  \
# 0                     S0: STATEMENT(red = 10)         5    30.9    33.5     7
# 1                    S1: STATEMENT(blue = 10)        21  107.31  109.09     7
# 3                   S2: STATEMENT(green = 20)        34  139.87  142.15     7
# 6      S3: STATEMENT(green + red + blue = 40)        40  152.57  153.59     7
# 7                  S4: STATEMENT(purple = 30)        48  179.32  181.84     7
# 8   S5: STATEMENT(green = 20 and purple = 30)        53  192.91  194.92     7
# 9                  S6: STATEMENT(yellow = 50)        59  212.92  213.95     7
# 12                 S7: STATEMENT(yellow = 50)       116  394.03  397.25     7
# 16                 S8: STATEMENT(yellow = 50)       133  457.21  458.84     7
#
#    Participant                                         Transcript
# 0            4     I will tell you that the red cube is ten grams
# 1            2                         blue block seems to be ten
# 3            3  yeah red block, blue block should be twenty as...
# 6            1     now red block, blue block, green block's forty
# 7            3            yeah i think purple block's yeah thirty
# 8            2                   So is twenty and there is thirty
# 9            2                                      Fifty I guess
# 12           1       ah yeah because yeah so yellow block's fifty
# 16           2               no okay i think yellow block's fifty
#     Begin Time - ss.msec  End Time - ss.msec               Common Ground  \
# 0                  30.90               34.59                    red = 10
# 1                 107.31              109.09                   blue = 10
# 3                 139.87              142.15                  green = 20
# 6                 152.57              153.59     green + red + blue = 40
# 7                 179.32              181.84                 purple = 30
# 8                 192.91              194.92  green = 20 and purple = 30
# 9                 212.92              213.95                 yellow = 50
# 12                395.75              397.25                 yellow = 50
# 16                458.08              458.84                 yellow = 50
#
#    Utterance   Start     End Group Participant  \
# 0          5    30.9    33.5     7           4
# 1         21  107.31  109.09     7           2
# 3         34  139.87  142.15     7           3
# 6         40  152.57  153.59     7           1
# 7         48  179.32  181.84     7           3
# 8         53  192.91  194.92     7           2
# 9         59  212.92  213.95     7           2
# 12       116  394.03  397.25     7           1
# 16       133  457.21  458.84     7           2
#
#                                            Transcript
# 0      I will tell you that the red cube is ten grams
# 1                          blue block seems to be ten
# 3   yeah red block, blue block should be twenty as...
# 6      now red block, blue block, green block's forty
# 7             yeah i think purple block's yeah thirty
# 8                    So is twenty and there is thirty
# 9                                       Fifty I guess
# 12       ah yeah because yeah so yellow block's fifty
# 16               no okay i think yellow block's fifty
# Processing Group 8
#     Begin Time - ss.msec  End Time - ss.msec  \
# 2                 10.090              11.430
# 7                 33.940              35.650
# 12                74.080              76.060
# 16               133.433             134.777
# 18               144.780             146.770
# 19               157.580             159.330
# 22               168.190             170.670
# 25               194.450             196.620
# 30               237.910             240.340
# 34               276.176             277.705
# 36               280.190             284.040
#
#                              Common Ground Utterance   Start     End Group  \
# 2               S1:  STATEMENT(green = 20)         1    8.07   11.55     8
# 7               S2: STATEMENT(purple = 30)         9   32.52   35.67     8
# 12  S3: STATEMENT(yellow < purple + green)        23   74.07   76.05     8
# 16              S4: STATEMENT(yellow > 40)        41   132.0  134.91     8
# 18         S5: STATEMENT(40 < yellow < 50)        43  144.78  146.76     8
# 19              S6: STATEMENT(yellow > 40)        44   155.4  157.66     8
# 22        S7: STATEMENT (40 < yellow > 50)        52  168.21  170.67     8
# 25              S8: STATEMENT(yellow < 50)        60  194.46  196.62     8
# 30               S9: STATEMENT (yellow=41)        77  237.93  239.33     8
# 34             S10: STATEMENT(yellow = 49)        87  272.91  277.75     8
# 36             S11: STATEMENT(yellow = 50)        90   280.2  284.04     8
#
#    Participant                                         Transcript
# 2            2                           yeah green is for twenty
# 7            2                    so twenty purple block's thirty
# 12           1                                 oh that's too left
# 16           1                  oh yellow block's more than forty
# 18           1                            Between forty and fifty
# 19           2       it's definitely not staying in between right
# 22           1          But we don't and less than fifty actually
# 25           1                                 Fifty is too heavy
# 30           1                        so yellow block's forty one
# 34           1  ok minus one it is yeah so yellow block is for...
# 36           3  ok so yellow block's probably meant to be just...
#     Begin Time - ss.msec  End Time - ss.msec            Common Ground  \
# 2                 10.090              11.430               green = 20
# 7                 33.940              35.650              purple = 30
# 12                74.080              76.060  yellow < purple + green
# 16               133.433             134.777              yellow > 40
# 18               144.780             146.770         40 < yellow < 50
# 19               157.580             159.330              yellow > 40
# 22               168.190             170.670         40 < yellow > 50
# 25               194.450             196.620              yellow < 50
# 30               237.910             240.340                yellow=41
# 34               276.176             277.705              yellow = 49
# 36               280.190             284.040              yellow = 50
#
#    Utterance   Start     End Group Participant  \
# 2          1    8.07   11.55     8           2
# 7          9   32.52   35.67     8           2
# 12        23   74.07   76.05     8           1
# 16        41   132.0  134.91     8           1
# 18        43  144.78  146.76     8           1
# 19        44   155.4  157.66     8           2
# 22        52  168.21  170.67     8           1
# 25        60  194.46  196.62     8           1
# 30        77  237.93  239.33     8           1
# 34        87  272.91  277.75     8           1
# 36        90   280.2  284.04     8           3
#
#                                            Transcript
# 2                            yeah green is for twenty
# 7                     so twenty purple block's thirty
# 12                                 oh that's too left
# 16                  oh yellow block's more than forty
# 18                            Between forty and fifty
# 19       it's definitely not staying in between right
# 22          But we don't and less than fifty actually
# 25                                 Fifty is too heavy
# 30                        so yellow block's forty one
# 34  ok minus one it is yeah so yellow block is for...
# 36  ok so yellow block's probably meant to be just...
# Processing Group 9
#     Begin Time - ss.msec  End Time - ss.msec  \
# 0                  22.14               24.27
# 1                  61.74               63.40
# 4                  96.66               97.83
# 5                 103.33              105.99
# 6                 108.23              111.27
# 7                 130.26              133.35
# 8                 133.38              135.67
# 10                160.22              164.84
# 11                168.42              170.83
#
#                                  Common Ground Utterance   Start     End  \
# 0                      S0: STATEMENT(red = 10)         3   22.14   24.27
# 1                    S1: STATEMENT(red = blue)        11   61.74    63.4
# 4            S2: STATEMENT(green = red + blue)        18   96.66   97.83
# 5        S3: STATEMENT(red = 10 and blue = 10)        19  103.33  105.99
# 6               S4: STATEMENT(green != purple)        21  108.23  111.27
# 7      S5: STATEMENT(green = 20 and blue = 10)        24  130.26  133.35
# 8                   S6: STATEMENT(purple = 30)        26  133.38  135.67
# 10      S7: STATEMENT(yellow = purple + green)        30  160.22  164.84
# 11  S8: STATEMENT(purple = 30 and yellow = 50)        33  168.42  170.83
#
#    Group Participant                                         Transcript
# 0      9           4                          The red cube is ten grams
# 1      9           2  i would say red block, blue block's equal prob...
# 4      9           2  yeah red block, blue block, green block's prob...
# 5      9           1                                  So we got ten ten
# 6      9           1                               Definitely not equal
# 7      9           1  green block, blue block was twenty and ten rig...
# 8      9           1        Look we have the thirty gram block and then
# 10     9           2  just like ever so slightly though so green blo...
# 11     9           3  purple block one was thirty so yellow block sh...
#     Begin Time - ss.msec  End Time - ss.msec                Common Ground  \
# 0                  22.14               24.27                     red = 10
# 1                  61.74               63.40                   red = blue
# 4                  96.66               97.83           green = red + blue
# 5                 103.33              105.99       red = 10 and blue = 10
# 6                 108.23              111.27              green != purple
# 7                 130.26              133.35     green = 20 and blue = 10
# 8                 133.38              135.67                  purple = 30
# 10                160.22              164.84      yellow = purple + green
# 11                168.42              170.83  purple = 30 and yellow = 50
#
#    Utterance   Start     End Group Participant  \
# 0          3   22.14   24.27     9           4
# 1         11   61.74    63.4     9           2
# 4         18   96.66   97.83     9           2
# 5         19  103.33  105.99     9           1
# 6         21  108.23  111.27     9           1
# 7         24  130.26  133.35     9           1
# 8         26  133.38  135.67     9           1
# 10        30  160.22  164.84     9           2
# 11        33  168.42  170.83     9           3
#
#                                            Transcript
# 0                           The red cube is ten grams
# 1   i would say red block, blue block's equal prob...
# 4   yeah red block, blue block, green block's prob...
# 5                                   So we got ten ten
# 6                                Definitely not equal
# 7   green block, blue block was twenty and ten rig...
# 8         Look we have the thirty gram block and then
# 10  just like ever so slightly though so green blo...
# 11  purple block one was thirty so yellow block sh...
# Processing Group 10
#     Begin Time - ss.msec  End Time - ss.msec  \
# 0                 24.775              26.487
# 4                 81.080              82.080
# 6                 97.000              98.000
# 8                101.850             102.850
# 12               118.170             119.170
# 13               127.250             128.250
# 15               141.910             142.910
# 17               201.560             202.560
# 18               216.000             217.000
# 20               253.240             254.240
# 21               268.130             269.130
# 23               273.000             274.000
# 25               285.570             286.570
# 27               304.000             305.000
# 28               306.260             307.260
# 29               311.480             312.480
#
#                                         Common Ground Utterance   Start  \
# 0                             S0: STATEMENT(red = 10)         5   24.01
# 4   S1: STATEMENT(green = 20 and blue = 10 and red...        20   79.58
# 6                           S2: STATEMENT(red = blue)        25    96.5
# 8   S3: STATEMENT(green = 20 and red = 10 and blue...        27  100.84
# 12                          S4: STATEMENT(red = blue)        34  117.46
# 13                      S5: STATEMENT(purple > green)        35  119.75
# 15                S6: STATEMENT(purple = green + red)        40  136.34
# 17                S7: STATEMENT(purple > green + red)        52  180.78
# 18                  S8: STATEMENT(purple = around 30)        54  203.33
# 20  S9: STATEMENT(purple = 30 and green = 20 and y...        63  247.61
# 21                        S10: STATEMENT(yellow < 50)        67  263.83
# 23                        S11: STATEMENT(yellow = 50)        70   270.0
# 25                        S12: STATEMENT(yellow < 50)        74  283.84
# 27                        S13: STATEMENT(yellow < 50)        81   303.0
# 28                        S14: STATEMENT(yellow = 50)        80  302.51
# 29  S15: STATEMENT(purple = 30 and green = 20 and ...        82  307.81
#
#        End Group Participant  \
# 0    26.75    10           4
# 4    82.08    10           3
# 6     98.0    10           3
# 8   102.85    10           3
# 12  118.87    10           2
# 13  128.25    10           3
# 15  142.91    10           1
# 17  202.56    10           2
# 18  216.41    10           2
# 20  254.24    10           2
# 21  268.91    10           3
# 23   274.0    10           2
# 25  286.57    10           2
# 27   305.0    10           2
# 28  307.26    10           3
# 29  312.48    10           1
#
#                                            Transcript
# 0      I will tell you that the red cube is ten grams
# 4   i guess green block is like twenty and red blo...
# 6   it looks like red block, blue block're fairly ...
# 8   right so then green block's twenty red block, ...
# 12             yeah red block, blue block're together
# 13  alright well now let's do green block, purple ...
# 15  i say green block, red block, purple block are...
# 17  i'm guessing it's a little bit to the left a l...
# 18  we we moved green block and checked the two te...
# 20  so purple block one's thirty and what's green ...
# 21  i mean it's not gonna go anywhere i guess it's...
# 23  But there's no like I mean between weights so ...
# 25  yellow block is like less than fifty less than...
# 27  yeah yeah it's it's almost settled down so yel...
# 28       should i oh yeah yellow block is fifty grams
# 29  so purple block was thirty right thirty green ...
#     Begin Time - ss.msec  End Time - ss.msec  \
# 0                 24.775              26.487
# 4                 81.080              82.080
# 6                 97.000              98.000
# 8                101.850             102.850
# 12               118.170             119.170
# 13               127.250             128.250
# 15               141.910             142.910
# 17               201.560             202.560
# 18               216.000             217.000
# 20               253.240             254.240
# 21               268.130             269.130
# 23               273.000             274.000
# 25               285.570             286.570
# 27               304.000             305.000
# 28               306.260             307.260
# 29               311.480             312.480
#
#                                         Common Ground Utterance   Start  \
# 0                                            red = 10         5   24.01
# 4               green = 20 and blue = 10 and red = 10        20   79.58
# 6                                          red = blue        25    96.5
# 8               green = 20 and red = 10 and blue = 10        27  100.84
# 12                                         red = blue        34  117.46
# 13                                     purple > green        35  119.75
# 15                               purple = green + red        40  136.34
# 17                               purple > green + red        52  180.78
# 18                                 purple = around 30        54  203.33
# 20         purple = 30 and green = 20 and yellow = 50        63  247.61
# 21                                        yellow < 50        67  263.83
# 23                                        yellow = 50        70   270.0
# 25                                        yellow < 50        74  283.84
# 27                                        yellow < 50        81   303.0
# 28                                        yellow = 50        80  302.51
# 29  purple = 30 and green = 20 and red = 10 and bl...        82  307.81
#
#        End Group Participant  \
# 0    26.75    10           4
# 4    82.08    10           3
# 6     98.0    10           3
# 8   102.85    10           3
# 12  118.87    10           2
# 13  128.25    10           3
# 15  142.91    10           1
# 17  202.56    10           2
# 18  216.41    10           2
# 20  254.24    10           2
# 21  268.91    10           3
# 23   274.0    10           2
# 25  286.57    10           2
# 27   305.0    10           2
# 28  307.26    10           3
# 29  312.48    10           1
#
#                                            Transcript
# 0      I will tell you that the red cube is ten grams
# 4   i guess green block is like twenty and red blo...
# 6   it looks like red block, blue block're fairly ...
# 8   right so then green block's twenty red block, ...
# 12             yeah red block, blue block're together
# 13  alright well now let's do green block, purple ...
# 15  i say green block, red block, purple block are...
# 17  i'm guessing it's a little bit to the left a l...
# 18  we we moved green block and checked the two te...
# 20  so purple block one's thirty and what's green ...
# 21  i mean it's not gonna go anywhere i guess it's...
# 23  But there's no like I mean between weights so ...
# 25  yellow block is like less than fifty less than...
# 27  yeah yeah it's it's almost settled down so yel...
# 28       should i oh yeah yellow block is fifty grams
# 29  so purple block was thirty right thirty green ...
